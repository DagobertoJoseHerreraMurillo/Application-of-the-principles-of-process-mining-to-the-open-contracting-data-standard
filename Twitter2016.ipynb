# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\Dagoberto'

# %%
import pandas

# %%
tweets = pandas.read_json("frackingMX.json", orient = 'records', lines = True)

# %%
tweets.size
# Out:
# 643008

# %%
tweets.shape
# Out:
# (40188, 16)

# %%
tweets.columns
# Out:
# Index(['date', 'hashtags', 'id', 'likes', 'link', 'location', 'mentions',
#        'replies', 'retweet', 'retweets', 'time', 'timezone', 'tweet',
#        'user_id', 'user_rt', 'username'],
#       dtype='object')

# %%
tweets.groupby(["username"]).nunique()
# Out:
#                  date  hashtags  id  likes  link  location  mentions  replies  \
# username
# 00_pablo            1         1   1      1     1         1         1        1
# 01ECO               1         1   1      1     1         1         1        1
# 02Digimon           1         1   1      1     1         1         1        1
# 05Cesgar            7         8   9      4     9         1         3        2
# 05Varf              2         1   2      1     2         1         2        1
# 06Charo             1         1   1      1     1         1         1        1
# 06ZUNIGA            1         1   1      1     1         1         1        1
# 0alfla              1         1   1      1     1         1         1        1
# 0corrupcionmex      1         1   1      1     1         1         1        1
# 0marGamo            1         1   1      1     1         1         1        1
# 0swald05            1         1   1      1     1         1         1        1
# ...

# %% [markdown]
# https://stackoverflow.com/questions/44259951/how-to-get-number-of-twitter-followers-from-a-list-of-users-with-lookupuser-fu

# %%
import requests

# %%
r = requests.get('https://www.healthcare.gov/what-is-the-health-insurance-marketplace.json')

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html lang=\'en\'>\n<head>\n  <meta content=\'IE=edge\' http-equiv=\'X-UA-Compatible\'/>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n  <meta name=\'viewport\' content=\'width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=5.0\'/>\n  <title>Sorry, we can\'t find that page | HealthCare.gov</title>\n  <link rel=\'shortcut icon\' href=\'/images/favicon.ico\' type=\'image/x-icon\' />\n  <link rel="alternate" type="application/rss+xml" title="Health Insurance Blog - Healthcare.gov" href="/blog/blog.rss" />\n  <link rel="P3Pv1" href="/w3c/p3p.xml" /><!-- Privacy Policy -->\n  <meta name="msvalidate.01" content="598A98B6EDF7624D92A421A892DC3A45"><!-- Bing validation -->\n  <meta name=\'search-title\' content="Sorry, we can\'t find that page" />\n  <meta name=\'content-type\' content=\'index\' />\n  <meta name=\'bite\' content="" />\n  <meta name=\'description\' content="" />\n  <meta property="og:title" content="Sorry, we can
# ...
