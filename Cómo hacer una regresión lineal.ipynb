# %%
http://scipy-lectures.org/packages/statistics/auto_examples/plot_regression_3d.html

# %%
# Original author: Thomas Haslwanter

import numpy as np
import matplotlib.pyplot as plt
import pandas

# For 3d plots. This import is necessary to have 3D plotting below
from mpl_toolkits.mplot3d import Axes3D

# For statistics. Requires statsmodels 5.0 or more
from statsmodels.formula.api import ols
# Analysis of Variance (ANOVA) on linear models
from statsmodels.stats.anova import anova_lm

# %%
t=pd.read_csv("Regresion3.csv")
t
# Out:
#         y   x1    x2    x3   x4   x5   x6   x7  x8   x9 ...   x12   x13  x14  \
# 0   2.500  262   494   349   78   97  359  136   0   14 ...     4   731  352
# 1   2.250   94   119   258    0  312   17    5  10   19 ...     0    60  175
# 2   2.250   76    91   100    0  312   17    5  10   19 ...     0    60  175
# 3   2.250   47   255   111   61   70   43   17   3   14 ...     0    97   51
# 4   3.125  182   928  2318   74  105  122  364   6  104 ...    14   431   85
# 5   1.375  120   631   593   11   80  114  177  27   26 ...     0   388   31
# 6   2.875   98   469  1120   13   19   66  101   0   10 ...     4   450  195
# 7   2.250   17   110   115    0   14    6   10   0    3 ...     0    13    9
# 8   2.250   41   250   246   17  112    0    4   0    5 ...     0    17  102
# 9   2.125   33   595   725   25   22   40   36   0    9 ...     0    52   14
# 10  2.875  208   436   585   15   88  148  270   5   68 ...     9   443  171
# ...

# %%
# Fit the model
model = ols("y ~ x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9 + x10 + x11 + x12 + x13 + x14 + x15 + x16 + x17 + x18 + x19 + x20 + x21", t).fit()

# Print the summary
print(model.summary())

print("\nRetrieving manually the parameter estimates:")
print(model._results.params)
# should be array([-4.99754526,  3.00250049, -0.50514907])

# Peform analysis of variance on fitted linear model
anova_results = anova_lm(model)

print('\nANOVA results')
print(anova_results)

plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     2.700
# Date:                Fri, 22 Mar 2019   Prob (F-statistic):            0.00122
# Time:                        17:40:26   Log-Likelihood:                -49.627
# No. Observations:                  86   AIC:                             143.3
# Df Residuals:                      64   BIC:                             197.2
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9843      0.112     17.708      0.000       1.760       2.208
# ...
