# %%
import pandas as pd
df = pd.read_json("todos.json", lines = False)

# %%
df
# Out:
#               created_at  cvedependencia  ejercicio    id nomdependencia  \
# 0    2018-10-04 19:08:14             901       2017     1
# 1    2018-10-04 19:08:14             901       2018     2
# 2    2018-10-04 19:08:14             901       2018     3
# 3    2018-10-04 19:08:14             901       2018     4
# 4    2018-10-04 19:08:14             901       2018     5
# 5    2018-10-04 19:08:14             901       2018     6
# 6    2018-10-04 19:08:14             901       2018     7
# 7    2018-10-04 19:08:14             901       2018     8
# 8    2018-10-04 19:08:14             901       2018     9
# 9    2018-10-04 19:08:14             901       2018    10
# 10   2018-10-04 19:08:14             901       2018    11
# 11   2018-10-04 19:08:14             901       2018    12
# 12   2018-10-04 19:08:14             901       2018    13
# 13   2018-10-04 19:08:14             901       2018    14
# 14   2018-10-04 19:08:14             901       2018    15
# ...

# %%
df.shape
# Out:
# (1314, 10)

# %%
df.dtypes
# Out:
# created_at        datetime64[ns]
# cvedependencia             int64
# ejercicio                  int64
# id                         int64
# nomdependencia            object
# ocdsid                    object
# published_date            object
# publisher_id               int64
# updated_at        datetime64[ns]
# uri                       object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
x=df["created_at"]
plt.plot(x)
plt.show()

# %%
import json
import pandas as pd
data = json.load(open("OCDS1.json"))

# %%
data
# Out:
# {'publishedDate': '2018-10-13T00:00:00-06:00',
#  'publisher': {'name': 'CDMX-SEFIN',
#   'scheme': 'http://www.contratosabiertos.cdmx.gob.mx',
#   'uid': '0901',
#   'uri': 'http://www.finanzas.df.gob.mx/'},
#  'releases': [{'awards': [{'date': '2015-11-12T00:00:00-06:00',
#      'description': 'SERVICIOS DE IMPRESIÓN DE DOCUMENTOS OFICIALES',
#      'documents': [{'datePublished': '2015-11-12T00:00:00-06:00',
#        'format': 'application/pdf',
#        'id': '1',
#        'language': 'es',
#        'title': 'OFICIO DE ADJUDICACION 3594',
#        'url': 'http://innovacion.finanzas.df.gob.mx/ocpsefin/INTERFASE2/GRP/OCDS/ARCHIVOS/adjudicacion_3594_20160505_141049.pdf'}],
#      'id': '1',
#      'items': [{'description': 'IMPRESION DE DOCUMENTOS OFICIALES',
#        'id': '10',
#        'quantity': 1,
#        'unit': {'name': 'SER'}},
#       {'description': 'IMPRESION DE DOCUMENTOS OFICIALES',
#        'id': '20',
#        'quantity': 1,
#        'unit': {'name': 'SER'}},
# ...
